# %% [markdown]
# <a href="https://colab.research.google.com/github/xushnozaxon/620/blob/main/XUSHNOZA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data:
x = 0.5 + np.arange(8)
y = [3.8,2.5,5.4,4.6,6.2,6.6,2.6,3.0]

# plot
fig, ax = plt.subplots()

ax.bar(x, y, width=1, edgecolor="white",
linewidth=0.7,color="red")

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8),yticks=np.arange(1, 8))

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(['OLMA','BEHI','NOK','UZUM'])
y = np.array([5000,15000,20000,30000])
plt.bar(x,y,color='green')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(['OLMA','BEHI','NOK','UZUM'])
y = np.array([5000,15000,20000,30000])
plt.barh(x,y,color='green')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([35,25,25,15])

mylabels = ["Apples","Banans","Cherries","Dates"]

mycolors=["green","yellow","red","grey"]

myexplode=[0,0,0,0]
plt.pie(y,labels=mylabels,startangle=90,
explode=myexplode,colors=mycolors)
plt.show()
